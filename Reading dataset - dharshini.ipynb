# %% [markdown]
# # Reading the (CSV,JSON,PARQUET)datasets

# %% [markdown]
# # *Importing Libraries*

# %%
import pandas as pd

# %%
import os

# %%
import numpy as np

# %%
import json

# %%
pip install pyarrow
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # *CSV dataset 1*

# %%
csv_path1="C:\\Users\\MAGIMA\\Documents\\Dharshini\\healthexp.csv"

# %% [markdown]
# # *Read CSV 1 dataset*

# %%
df_csv1=pd.read_csv(csv_path1)

# %%
df_csv1
# Out:
#      Year        Country  Spending_USD  Life_Expectancy
# 0    1970        Germany       252.311             70.6
# 1    1970         France       192.143             72.2
# 2    1970  Great Britain       123.993             71.9
# 3    1970          Japan       150.437             72.0
# 4    1970            USA       326.961             70.9
# ..    ...            ...           ...              ...
# 269  2020        Germany      6938.983             81.1
# 270  2020         France      5468.418             82.3
# 271  2020  Great Britain      5018.700             80.4
# 272  2020          Japan      4665.641             84.7
# 273  2020            USA     11859.179             77.0
#
# [274 rows x 4 columns]

# %% [markdown]
# # *CSV dataset 2*

# %%
csv_path2="C:\\Users\\MAGIMA\\Documents\\Dharshini\\chickweight.csv"

# %% [markdown]
# # *Read CSV 2 dataset*

# %%
df_csv2=pd.read_csv(csv_path2)

# %%
df_csv2
# Out:
#      weight  Time  Chick  Diet
# 0        42     0      1     1
# 1        51     2      1     1
# 2        59     4      1     1
# 3        64     6      1     1
# 4        76     8      1     1
# ..      ...   ...    ...   ...
# 573     175    14     50     4
# 574     205    16     50     4
# 575     234    18     50     4
# 576     264    20     50     4
# 577     264    21     50     4
#
# [578 rows x 4 columns]

# %% [markdown]
# # *CSV dataset 3*

# %%
csv_path3="C:\\Users\\MAGIMA\\Documents\\Dharshini\\taxis.csv"

# %% [markdown]
# # *Read CSV 3 dataset*

# %%
df_csv3=pd.read_csv(csv_path3)

# %%
df_csv3
# Out:
#                    pickup              dropoff  passengers  distance  fare  \
# 0     2019-03-23 20:21:09  2019-03-23 20:27:24           1      1.60   7.0
# 1     2019-03-04 16:11:55  2019-03-04 16:19:00           1      0.79   5.0
# 2     2019-03-27 17:53:01  2019-03-27 18:00:25           1      1.37   7.5
# 3     2019-03-10 01:23:59  2019-03-10 01:49:51           1      7.70  27.0
# 4     2019-03-30 13:27:42  2019-03-30 13:37:14           3      2.16   9.0
# ...                   ...                  ...         ...       ...   ...
# 6428  2019-03-31 09:51:53  2019-03-31 09:55:27           1      0.75   4.5
# 6429  2019-03-31 17:38:00  2019-03-31 18:34:23           1     18.74  58.0
# 6430  2019-03-23 22:55:18  2019-03-23 23:14:25           1      4.14  16.0
# 6431  2019-03-04 10:09:25  2019-03-04 10:14:29           1      1.12   6.0
# 6432  2019-03-13 19:31:22  2019-03-13 19:48:02           1      3.85  15.0
#
# ...

# %% [markdown]
# # *JSON dataset 1*

# %%
json_path1="C:\\Users\\MAGIMA\\Documents\\Dharshini\\airports.json"

# %%
with open(json_path1,"r") as f:
    raw_data1=json.load(f)

# %% [markdown]
# # *Reading JSON 1 dataset*

# %%
df_json1=pd.json_normalize(raw_data1)

# %%
df_json1
# Out:
#                                             airports
# 0  [{'code': 'ATL', 'name': 'Hartsfield-Jackson A...

# %% [markdown]
# # *JSON dataset 2*

# %%
json_path2="C:\\Users\\MAGIMA\\Documents\\Dharshini\\file-extensions.json"

# %%
with open(json_path2,"r") as f:
    raw_data2=json.load(f)

# %% [markdown]
# # *Reading JSON 2 dataset*

# %%
df_json2=pd.json_normalize(raw_data2)

# %%
df_json2
# Out:
#                                           extensions
# 0  [{'extension': '.json', 'type': 'Data', 'mime_...

# %% [markdown]
# # *JSON dataset 3*

# %%
json_path3="C:\\Users\\MAGIMA\\Documents\\Dharshini\\http-status-codes.json"

# %%
with open(json_path3,"r") as f:
    raw_data3=json.load(f)

# %% [markdown]
# # *Reading JSON 3 dataset*

# %%
df_json3=pd.json_normalize(raw_data3)

# %%
df_json3
# Out:
#                                         status_codes
# 0  [{'code': 100, 'message': 'Continue', 'categor...

# %% [markdown]
# # *Parquet dataset 1*

# %%
parquet_path1="C:\\Users\\MAGIMA\\Documents\\Dharshini\\sample-parquet-files-sample-4.parquet"

# %% [markdown]
# # *Reading parquet 1 dataset*

# %%
df_parquet1=pd.read_parquet(parquet_path1,engine="pyarrow")

# %%
df_parquet1
# Out:
#        column0   column1
# 0        first      last
# 1        Jorge     Frank
# 2       Hunter    Moreno
# 3       Esther    Guzman
# 4       Dennis  Stephens
# ..         ...       ...
# 96       Brett    Miller
# 97    Adelaide    Phelps
# 98         Leo   Walters
# 99      Samuel   Schmidt
# 100  Elizabeth    Gordon
#
# [101 rows x 2 columns]

# %% [markdown]
# # *Parquet dataset 2*

# %%
parquet_path2="C:\\Users\\MAGIMA\\Documents\\Dharshini\\sample-parquet-files-sample-5.parquet"

# %% [markdown]
# # *Reading parquet 2 dataset*

# %%
df_parquet2=pd.read_parquet(parquet_path2,engine="pyarrow")

# %%
df_parquet2
# Out:
#      column0  column1
# 0      first     last
# 1      Lewis   Taylor
# 2       Alan  Schultz
# 3       Dora  Carroll
# 4       Ryan   Daniel
# ..       ...      ...
# 296    Alvin   Snyder
# 297  Matilda    Silva
# 298    Ethan  Morales
# 299  Bernice   Cortez
# 300    Jimmy   Wright
#
# [301 rows x 2 columns]

# %% [markdown]
# # *Parquet dataset 3*

# %%
parquet_path3="C:\\Users\\MAGIMA\\Documents\\Dharshini\\sample-parquet-files-sample-6.parquet"

# %% [markdown]
# # *Reading parquet 2 dataset*

# %%
df_parquet3=pd.read_parquet(parquet_path3,engine="pyarrow")

# %%
df_parquet3
# Out:
#       column0   column1
# 0       first      last
# 1        Edna      Moss
# 2      Harvey    Carter
# 3        Leah   Douglas
# 4     Ricardo     Owens
# ...       ...       ...
# 996    Donald      Paul
# 997    Amanda     Green
# 998    Myrtie    Walton
# 999      Todd  Johnston
# 1000    Essie      Carr
#
# [1001 rows x 2 columns]
